# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
iris=sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(iris.groupby("species").size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
sns.scatterplot(x="sepal_length",y="sepal_width",data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="sepal_length",y="sepal_width",data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="sepal_length",y="sepal_width",data=iris,hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="sepal_length",y="sepal_width",data=iris,hue="species",size="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="sepal_length",y="sepal_width",data=iris,hue="species",s=200)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="sepal_length",y="sepal_width",data=iris,hue="species",s=200,alpha=0.8)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="sepal_length",y="sepal_width",data=iris,style="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="sepal_length",y="sepal_width",data=iris,style="species",hue="species",s=200)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="sepal_length",y="sepal_width",data=iris,style="species")
plt.savefig("example_scatter.jpg")

# %%
sns.rugplot(x="petal_length",data=iris,height=0.2)
# Out:
# <Axes: xlabel='petal_length'>

# %%
sns.rugplot(x="petal_width",y="petal_length",data=iris,height=0.2)
# Out:
# <Axes: xlabel='petal_width', ylabel='petal_length'>

# %%
sns.displot(x="petal_length",data=iris)

# %%
sns.displot(x="sepal_length",data=iris,kde=True,rug=True)

# %%
sns.histplot(data=iris,x="petal_length")
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data=iris,x="petal_length",bins=100,kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data=iris,x="petal_length",bins=100)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
iris.hist(edgecolor="green",linewidth=3.0,figsize=(18,8))
plt.show( )

# %%
data=[1,2,3,4,5,6,7,8,9,0]
sns.boxplot(data=data)
# Out:
# <Axes: >

# %%
sns.boxplot(x="species",y="petal_length",data=iris)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
plt.figure(figsize=(10,8),dpi=200)
sns.countplot(x="sepal_length",data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='count'>

# %%
plt.figure(figsize=(10,8),dpi=200)
sns.countplot(x="sepal_length",data=iris,hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='count'>

# %%
plt.figure(figsize=(10,8),dpi=200)
sns.barplot(x="sepal_length",y="sepal_width",data=iris,estimator=np.mean)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.subplot(2,2,1)
sns.violinplot(x="species",y="sepal_length",data=iris,inner=None)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>
