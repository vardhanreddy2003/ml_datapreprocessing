# %%
print(4)
# Out:
# 4

# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([1,2,3,4,5])
print(s)
print(s.describe())
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
print(s.mean())
print(s.std())
print(s.max())
print(s.sum())
print(s.min())
# Out:
# 3.0
# 1.5811388300841898
# 5
# 15
# 1

# %%
s=pd.Series([9,4,6,1,2,4])
sorted=s.sort_values()
print(sorted)
print(sorted.sort_index())
# Out:
# 3    1
# 4    2
# 1    4
# 5    4
# 2    6
# 0    9
# dtype: int64
# 0    9
# 1    4
# 2    6
# 3    1
# 4    2
# 5    4
# dtype: int64

# %%
s=pd.Series([1,2,3,4])
dropped=s.drop(0)
print(dropped)
s.drop(1,inplace=True)
print(s)
# Out:
# 1    2
# 2    3
# 3    4
# dtype: int64
# 0    1
# 2    3
# 3    4
# dtype: int64

# %%
s=pd.Series([1,np.nan,3,np.nan,4])
print(s)
print(s.isnull())
print(s.notnull())
filled=s.fillna(22)
print(filled)
# Out:
# 0    1.0
# 1    NaN
# 2    3.0
# 3    NaN
# 4    4.0
# dtype: float64
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# dtype: bool
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool
# 0     1.0
# 1    22.0
# 2     3.0
# 3    22.0
# 4     4.0
# dtype: float64

# %%
s=pd.Series([1,2,np.nan,4,np.nan])
dropped=s.dropna()
print(dropped)
print(s)
# Out:
# 0    1.0
# 1    2.0
# 3    4.0
# dtype: float64
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    NaN
# dtype: float64

# %%
s=pd.Series([1,2,3,4,5])
print(s.iloc[0])
print(s.iloc[-1])
print(s.iloc[4])
# Out:
# 1
# 5
# 5

# %%
s=pd.Series([1,2,3,4],index=["a","b","c","d"])
print(s)
print(s.iloc[0:2])
print(s.loc["c"])
print(s.loc["a":"c"])
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64
# a    1
# b    2
# dtype: int64
# 3
# a    1
# b    2
# c    3
# dtype: int64

# %%
s=pd.Series([1,2,3,4,5])
print(s.sum())
print(s.cumsum())
# Out:
# 15
# 0     1
# 1     3
# 2     6
# 3    10
# 4    15
# dtype: int64

# %%
aggregrated=s.aggregate(["sum","mean","std","min","max"])
print(aggregrated)
# Out:
# sum     15.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# max      5.000000
# dtype: float64

# %%
data = {
    'Name': ['Dodagatta Nihar', 'Vignesh', 'Maheshwar', 'Naman', 'Naveen', 'Shreya', 'Varsha', 'Varun'],
    'Role': ['Founder', 'Growth Manager', 'Community Manager', 'Community Manager', 'Community Manager',
             'Course Designer', 'Course Designer', 'Public Relations Manager'],
    'Phone Number': ['111-111-1111', '222-222-2222', '333-333-3333', '444-444-4444',
                     '555-555-5555', '666-666-6666', '777-777-7777', '888-888-8888'],
    'Email': ['nihar@masscoders.tech', 'vignesh@masscoders.tech', 'maheshwar@masscoders.tech', 'naman@masscoders.tech',
              'naveen@masscoders.tech', 'shreya@masscoders.tech', 'varsha@masscoders.tech', 'varun@masscoders.tech'],
    'Address': ['123, MG Road, Bangalore', '456, Brigade Road, Chennai', '789, Rajaji Nagar, Mumbai', '101, Indira Nagar, Delhi',
                '202, Koramangala, Hyderabad', '303, JP Nagar, Kolkata', '404, Electronic City, Pune', '505, HSR Layout, Ahmedabad'],
    'Blood Group': ['A+', 'B-', 'O+', 'AB+', 'A-', 'B+', 'O-', 'AB-']
}
dataframe=pd.DataFrame(data)
dataframe.head(7)
# Out:
#               Name               Role  Phone Number  \
# 0  Dodagatta Nihar            Founder  111-111-1111
# 1          Vignesh     Growth Manager  222-222-2222
# 2        Maheshwar  Community Manager  333-333-3333
# 3            Naman  Community Manager  444-444-4444
# 4           Naveen  Community Manager  555-555-5555
# 5           Shreya    Course Designer  666-666-6666
# 6           Varsha    Course Designer  777-777-7777
#
#                        Email                      Address Blood Group
# 0      nihar@masscoders.tech      123, MG Road, Bangalore          A+
# 1    vignesh@masscoders.tech   456, Brigade Road, Chennai          B-
# 2  maheshwar@masscoders.tech    789, Rajaji Nagar, Mumbai          O+
# 3      naman@masscoders.tech     101, Indira Nagar, Delhi         AB+
# 4     naveen@masscoders.tech  202, Koramangala, Hyderabad          A-
# 5     shreya@masscoders.tech       303, JP Nagar, Kolkata          B+
# ...

# %%
dataframe
# Out:
#               Name                      Role  Phone Number  \
# 0  Dodagatta Nihar                   Founder  111-111-1111
# 1          Vignesh            Growth Manager  222-222-2222
# 2        Maheshwar         Community Manager  333-333-3333
# 3            Naman         Community Manager  444-444-4444
# 4           Naveen         Community Manager  555-555-5555
# 5           Shreya           Course Designer  666-666-6666
# 6           Varsha           Course Designer  777-777-7777
# 7            Varun  Public Relations Manager  888-888-8888
#
#                        Email                      Address Blood Group
# 0      nihar@masscoders.tech      123, MG Road, Bangalore          A+
# 1    vignesh@masscoders.tech   456, Brigade Road, Chennai          B-
# 2  maheshwar@masscoders.tech    789, Rajaji Nagar, Mumbai          O+
# 3      naman@masscoders.tech     101, Indira Nagar, Delhi         AB+
# 4     naveen@masscoders.tech  202, Koramangala, Hyderabad          A-
# ...

# %%
 #Team roles data
roles_data = {
    'name': ['Dodagatta Nihar', 'Vignesh', 'Maheshwar', 'Naman', 'Naveen', 'Shreya', 'Varsha', 'Varun'],
    'Role': ['Founder', 'Growth Manager', 'Community Manager', 'Community Manager', 'Community Manager',
             'Course Designer', 'Course Designer', 'Public Relations Manager']
}

roles_df = pd.DataFrame(roles_data)
print(roles_df)
# Contact information data
contact_data = {
    'name': ['Dodagatta Nihar', 'Vignesh', 'Maheshwar', 'Naman', 'Naveen', 'Shreya', 'Varsha', 'Varun'],
    'Phone Number': ['111-111-1111', '222-222-2222', '333-333-3333', '444-444-4444',
                     '555-555-5555', '666-666-6666', '777-777-7777', '888-888-8888'],
    'Email': ['nihar@masscoders.tech', 'vignesh@masscoders.tech', 'maheshwar@masscoders.tech', 'naman@masscoders.tech',
              'naveen@masscoders.tech', 'shreya@masscoders.tech', 'varsha@masscoders.tech', 'varun@masscoders.tech']
}

contact_df = pd.DataFrame(contact_data)
print(contact_df)
# Out:
#               name                      Role
# 0  Dodagatta Nihar                   Founder
# 1          Vignesh            Growth Manager
# 2        Maheshwar         Community Manager
# 3            Naman         Community Manager
# 4           Naveen         Community Manager
# 5           Shreya           Course Designer
# 6           Varsha           Course Designer
# 7            Varun  Public Relations Manager
#               name  Phone Number                      Email
# 0  Dodagatta Nihar  111-111-1111      nihar@masscoders.tech
# 1          Vignesh  222-222-2222    vignesh@masscoders.tech
# 2        Maheshwar  333-333-3333  maheshwar@masscoders.tech
# 3            Naman  444-444-4444      naman@masscoders.tech
# 4           Naveen  555-555-5555     naveen@masscoders.tech
# 5           Shreya  666-666-6666     shreya@masscoders.tech
# 6           Varsha  777-777-7777     varsha@masscoders.tech
# 7            Varun  888-888-8888      varun@masscoders.tech

# %%
merged_df=pd.merge(roles_df,contact_df,on="name")
merged_df
# Out:
#               name                      Role  Phone Number  \
# 0  Dodagatta Nihar                   Founder  111-111-1111
# 1          Vignesh            Growth Manager  222-222-2222
# 2        Maheshwar         Community Manager  333-333-3333
# 3            Naman         Community Manager  444-444-4444
# 4           Naveen         Community Manager  555-555-5555
# 5           Shreya           Course Designer  666-666-6666
# 6           Varsha           Course Designer  777-777-7777
# 7            Varun  Public Relations Manager  888-888-8888
#
#                        Email
# 0      nihar@masscoders.tech
# 1    vignesh@masscoders.tech
# 2  maheshwar@masscoders.tech
# 3      naman@masscoders.tech
# 4     naveen@masscoders.tech
# 5     shreya@masscoders.tech
# 6     varsha@masscoders.tech
# 7      varun@masscoders.tech

# %%
student_data = {
    'name': ["vardhan",'jaya', 'Maheshwar', 'Naman',"bunny"],
    'Role': [ "manager",'Growth Manager', 'Community Manager', 'Community Manager', 'Community Manager']
}
student_data_df=pd.DataFrame(student_data)
contact_data = {
    'name': ['vardhan', 'jaya', 'Maheshwar',"Naman","bunny"],
    'Phone Number': ['111-111-1111', '222-222-2222', '333-333-3333', '444-444-4444',
                     '555-555-5555'],
    'Email': ['nihar@masscoders.tech', 'vignesh@masscoders.tech', 'maheshwar@masscoders.tech', 'naman@masscoders.tech',
              'naveen@masscoders.tech']
}
contact_data_df=pd.DataFrame(contact_data)
merged_df=pd.merge(student_data_df,contact_data_df,on="name")
print(merged_df)
# Out:
#         name               Role  Phone Number                      Email
# 0    vardhan            manager  111-111-1111      nihar@masscoders.tech
# 1       jaya     Growth Manager  222-222-2222    vignesh@masscoders.tech
# 2  Maheshwar  Community Manager  333-333-3333  maheshwar@masscoders.tech
# 3      Naman  Community Manager  444-444-4444      naman@masscoders.tech
# 4      bunny  Community Manager  555-555-5555     naveen@masscoders.tech

# %%
df=pd.read_csv(r"C:/Users/dell/Downloads/archive/filmtv_movies.csv")
dfi=pd.DataFrame(df)
dfi.head(4)
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
# 3         18                                        Diner  1982     Comedy
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
# 2        91  United States                           Don Chaffey
# 3        95  United States                        Barry Levinson
#
#                                               actors  avg_vote  critics_vote  \
# 0                                                NaN       7.7           8.0
# 1  Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5           6.0
# ...

# %%
df.tail(10)
# Out:
#        filmtv_id                      title  year      genre  duration  \
# 41389     232184                    Nowhere  2023   Thriller       109
# 41390     232203     Mes petites amoureuses  1974      Drama       123
# 41391     232755                Organ Trail  2023    Western       112
# 41392     232757      Hidden Family Secrets  2021   Thriller        87
# 41393     232816       La stoccata vincente  2023  Biography       107
# 41394     232817         Gold Digger Killer  2021   Thriller        87
# 41395     232893        Addio al nubilato 2  2023     Comedy        90
# 41396     232915                Konferensen  2023     Horror       100
# 41397     232919                  Ballelina  2023   Thriller        92
# 41398     232920  Invitación a un Asesinato  2023   Thriller        92
#
#                      country             directors  \
# 41389                  Spain          Albert Pintó
# 41390                 France         Jean Eustache
# ...

# %%
df.shape
# Out:
# (41399, 19)

# %%
df.columns
# Out:
# Index(['filmtv_id', 'title', 'year', 'genre', 'duration', 'country',
#        'directors', 'actors', 'avg_vote', 'critics_vote', 'public_vote',
#        'total_votes', 'description', 'notes', 'humor', 'rhythm', 'effort',
#        'tension', 'erotism'],
#       dtype='object')

# %%
df.dtypes
# Out:
# filmtv_id         int64
# title            object
# year              int64
# genre            object
# duration          int64
# country          object
# directors        object
# actors           object
# avg_vote        float64
# critics_vote    float64
# public_vote     float64
# total_votes       int64
# description      object
# notes            object
# humor             int64
# rhythm            int64
# effort            int64
# tension           int64
# erotism           int64
# dtype: object

# %%
df.describe()
# Out:
#            filmtv_id          year      duration      avg_vote  critics_vote  \
# count   41399.000000  41399.000000  41399.000000  41399.000000  36703.000000
# mean    57746.410179   1993.505302    100.537163      5.801522      5.796077
# std     59962.095730     23.685612     27.260962      1.403861      1.593062
# min         2.000000   1897.000000     41.000000      1.000000      1.000000
# 25%     15857.000000   1976.000000     90.000000      4.800000      4.670000
# 50%     36266.000000   2001.000000     96.000000      5.900000      6.000000
# 75%     70935.000000   2013.000000    107.000000      6.900000      7.000000
# max    232920.000000   2023.000000   1525.000000     10.000000     10.000000
#
#         public_vote   total_votes         humor        rhythm        effort  \
# count  41205.000000  41399.000000  41399.000000  41399.000000  41399.000000
# mean       5.924135     36.986763      0.577381      1.345347      0.684847
# ...

# %%
titles=df.loc[:,"title"]
titles
# Out:
# 0        Bugs Bunny's Third Movie: 1001 Rabbit Tales
# 1                          18 anni tra una settimana
# 2                                   Ride a Wild Pony
# 3                                              Diner
# 4                    A che servono questi quattrini?
#                             ...
# 41394                             Gold Digger Killer
# 41395                            Addio al nubilato 2
# 41396                                    Konferensen
# 41397                                      Ballelina
# 41398                      Invitación a un Asesinato
# Name: title, Length: 41399, dtype: object

# %%
subset=df.loc[:10,["title","year","genre"]]
subset
# Out:
#                                           title  year      genre
# 0   Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982  Animation
# 1                     18 anni tra una settimana  1991      Drama
# 2                              Ride a Wild Pony  1976   Romantic
# 3                                         Diner  1982     Comedy
# 4               A che servono questi quattrini?  1942     Comedy
# 5                        The Uranian Conspiracy  1978        Spy
# 6                             A ciascuno il suo  1967      Drama
# 7                                     Dead-Bang  1989      Crime
# 8                           A... come assassino  1966   Thriller
# 9                                At Close Range  1986      Drama
# 10                    A Ghentar si muore facile  1968  Adventure

# %%
dramas=df.loc[df["genre"]=="Drama"]
dramas
# Out:
#        filmtv_id                      title  year  genre  duration  \
# 1              3  18 anni tra una settimana  1991  Drama        98
# 6             22          A ciascuno il suo  1967  Drama        93
# 9             26             At Close Range  1986  Drama       115
# 11            32    Sleeping with the Enemy  1990  Drama        96
# 18            49                  Fail-Safe  1964  Drama       110
# ...          ...                        ...   ...    ...       ...
# 41368     229838           Tereddüt Çizgisi  2023  Drama        84
# 41370     229865                     Stolen  2023  Drama        92
# 41371     229881                       Árni  2023  Drama       103
# 41372     229883              Kanata no uta  2023  Drama        84
# 41390     232203     Mes petites amoureuses  1974  Drama       123
#
#                               country      directors  \
# 1                               Italy  Luigi Perelli
# ...

# %%
multiple_condition=df.loc[(df["genre"]=="Drama")&(df["avg_vote"]>7.0)]
multiple_condition
# Out:
#        filmtv_id                     title  year  genre  duration  \
# 6             22         A ciascuno il suo  1967  Drama        93
# 9             26            At Close Range  1986  Drama       115
# 18            49                 Fail-Safe  1964  Drama       110
# 30            70  Can You Feel Me Dancing?  1986  Drama       120
# 44            92                 Accattone  1961  Drama       120
# ...          ...                       ...   ...    ...       ...
# 41320     226639                Sambizanga  1972  Drama        97
# 41349     229784                The Burial  2023  Drama       126
# 41355     229808      Aku wa sonzai shinai  2023  Drama       106
# 41366     229832       Magyarázat mindenre  2023  Drama       151
# 41390     232203    Mes petites amoureuses  1974  Drama       123
#
#                  country            directors  \
# 6                  Italy           Elio Petri
# 9          United States          James Foley
# ...

# %%
df.head(5)
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
# 3         18                                        Diner  1982     Comedy
# 4         20              A che servono questi quattrini?  1942     Comedy
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
# 2        91  United States                           Don Chaffey
# 3        95  United States                        Barry Levinson
# 4        85          Italy                        Esodo Pratelli
#
#                                               actors  avg_vote  critics_vote  \
# ...

# %%
print(df.iloc[0])
# Out:
# filmtv_id                                                       2
# title                 Bugs Bunny's Third Movie: 1001 Rabbit Tales
# year                                                         1982
# genre                                                   Animation
# duration                                                       76
# country                                             United States
# directors                    David Detiege, Art Davis, Bill Perez
# actors                                                        NaN
# avg_vote                                                      7.7
# critics_vote                                                  8.0
# public_vote                                                   7.0
# total_votes                                                    22
# description     With two protruding front teeth, a slightly sl...
# notes           These are many small independent stories, whic...
# ...

# %%
specific_data=df.iloc[10,[1,2,4]]
specific_data
# Out:
# title       A Ghentar si muore facile
# year                             1968
# duration                          101
# Name: 10, dtype: object

# %%
specific_data=df.iloc[10:15,[1,2]]
specific_data
# Out:
#                                    title  year
# 10             A Ghentar si muore facile  1968
# 11               Sleeping with the Enemy  1990
# 12                   In Bed With Madonna  1990
# 13                    Bowery at Midnight  1942
# 14  A mezzanotte va la ronda del piacere  1975

# %%
a=df.at[0,"title"]
a
# Out:
# "Bugs Bunny's Third Movie: 1001 Rabbit Tales"

# %%
recent_movies=df.loc[df["year"]>2010]
recent_movies
# Out:
#        filmtv_id                      title  year      genre  duration  \
# 22817      39955           The Tree of Life  2011      Drama       138
# 23725      41448        Season of the Witch  2011  Adventure        95
# 24186      42398                   Restless  2011      Drama        95
# 24426      42847             Qualunquemente  2011  Grotesque        96
# 24427      42848  Una sconfinata giovinezza  2011      Drama        98
# ...          ...                        ...   ...        ...       ...
# 41394     232817         Gold Digger Killer  2021   Thriller        87
# 41395     232893        Addio al nubilato 2  2023     Comedy        90
# 41396     232915                Konferensen  2023     Horror       100
# 41397     232919                  Ballelina  2023   Thriller        92
# 41398     232920  Invitación a un Asesinato  2023   Thriller        92
#
#                      country           directors  \
# 22817          United States     Terrence Malick
# ...

# %%
b=df.loc[(df["year"]>2011)&(df["duration"]>75)]
b
# Out:
#        filmtv_id                                title  year       genre  \
# 25023      43880               The Amazing Spider-man  2012  Super-hero
# 25157      44163    The Hobbit: An Unexpected Journey  2012   Adventure
# 25158      44164  The Hobbit: The Desolation of Smaug  2013   Adventure
# 25309      44499  Extremely Loud and Incredibly Close  2012       Drama
# 25481      44774                          Big Miracle  2012       Drama
# ...          ...                                  ...   ...         ...
# 41394     232817                   Gold Digger Killer  2021    Thriller
# 41395     232893                  Addio al nubilato 2  2023      Comedy
# 41396     232915                          Konferensen  2023      Horror
# 41397     232919                            Ballelina  2023    Thriller
# 41398     232920            Invitación a un Asesinato  2023    Thriller
#
#        duration                     country           directors  \
# ...

# %% [markdown]
# Updating rows and coloumns

# %%
df.drop(labels="title",axis=1)
# Out:
#        filmtv_id  year      genre  duration                country  \
# 0              2  1982  Animation        76          United States
# 1              3  1991      Drama        98                  Italy
# 2             17  1976   Romantic        91          United States
# 3             18  1982     Comedy        95          United States
# 4             20  1942     Comedy        85                  Italy
# ...          ...   ...        ...       ...                    ...
# 41394     232817  2021   Thriller        87  Canada, United States
# 41395     232893  2023     Comedy        90                  Italy
# 41396     232915  2023     Horror       100                 Sweden
# 41397     232919  2023   Thriller        92            South Korea
# 41398     232920  2023   Thriller        92                 Mexico
#
#                                   directors  \
# 0      David Detiege, Art Davis, Bill Perez
# 1                             Luigi Perelli
# ...

# %%
df.at[0,"year"]=1783
df.head(1)
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1783  Animation
#
#    duration        country                             directors actors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez    NaN
#
#    avg_vote  critics_vote  public_vote  total_votes  \
# 0       7.7           8.0          7.0           22
#
#                                          description  \
# 0  With two protruding front teeth, a slightly sl...
#
#                                                notes  humor  rhythm  effort  \
# 0  These are many small independent stories, whic...      3       3       0
#
#    tension  erotism
# 0        0        0

# %%
df.loc[df["duration"]<90,"effort"]=2
df.head(4)
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1783  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
# 3         18                                        Diner  1982     Comedy
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
# 2        91  United States                           Don Chaffey
# 3        95  United States                        Barry Levinson
#
#                                               actors  avg_vote  critics_vote  \
# 0                                                NaN       7.7           8.0
# 1  Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5           6.0
# ...

# %%
df["newcoloum"]="default"
df.head(2)
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1783  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
#
#                                               actors  avg_vote  critics_vote  \
# 0                                                NaN       7.7           8.0
# 1  Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5           6.0
#
#    public_vote  total_votes  \
# 0          7.0           22
# 1          7.0            4
#
#                                          description  \
# 0  With two protruding front teeth, a slightly sl...
# 1  Samantha, not yet eighteen, leaves the comfort...
#
# ...

# %%
df.drop(labels="newcoloum",axis=1,inplace=True)
df
# Out:
#        filmtv_id                                        title  year  \
# 0              2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1783
# 1              3                    18 anni tra una settimana  1991
# 2             17                             Ride a Wild Pony  1976
# 3             18                                        Diner  1982
# 4             20              A che servono questi quattrini?  1942
# ...          ...                                          ...   ...
# 41394     232817                           Gold Digger Killer  2021
# 41395     232893                          Addio al nubilato 2  2023
# 41396     232915                                  Konferensen  2023
# 41397     232919                                    Ballelina  2023
# 41398     232920                    Invitación a un Asesinato  2023
#
#            genre  duration                country  \
# 0      Animation        76          United States
# ...

# %%
df.loc[df["avg_vote"]>6,["top_rated","must_watch"]]=[True,True]
df.head(5)
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1783  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
# 3         18                                        Diner  1982     Comedy
# 4         20              A che servono questi quattrini?  1942     Comedy
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
# 2        91  United States                           Don Chaffey
# 3        95  United States                        Barry Levinson
# 4        85          Italy                        Esodo Pratelli
#
#                                               actors  avg_vote  critics_vote  \
# ...

# %%
d=df.loc[(df["duration"]>90)&(df["avg_vote"]>6.0)]
d.head(7)
# Out:
#     filmtv_id                      title  year   genre  duration  \
# 1           3  18 anni tra una settimana  1991   Drama        98
# 3          18                      Diner  1982  Comedy        95
# 6          22          A ciascuno il suo  1967   Drama        93
# 9          26             At Close Range  1986   Drama       115
# 15         38               Mr. Majestyk  1974  Action       105
# 18         49                  Fail-Safe  1964   Drama       110
# 19         51           Some Like It Hot  1959  Comedy       120
#
#           country          directors  \
# 1           Italy      Luigi Perelli
# 3   United States     Barry Levinson
# 6           Italy         Elio Petri
# 9   United States        James Foley
# 15  United States  Richard Fleischer
# 18  United States       Sidney Lumet
# 19  United States       Billy Wilder
#
#                                                actors  avg_vote  critics_vote  \
# ...

# %%
df["duration_category"]=df["duration"].apply(lambda x:"long" if x>120 else "short")
df.head(5)
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1783  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
# 3         18                                        Diner  1982     Comedy
# 4         20              A che servono questi quattrini?  1942     Comedy
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
# 2        91  United States                           Don Chaffey
# 3        95  United States                        Barry Levinson
# 4        85          Italy                        Esodo Pratelli
#
#                                               actors  avg_vote  critics_vote  \
# ...

# %%
df["voting"]=df["duration"].apply(lambda x:x*2)
df.head(3)
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1783  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
# 2        91  United States                           Don Chaffey
#
#                                               actors  avg_vote  critics_vote  \
# 0                                                NaN       7.7           8.0
# 1  Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5           6.0
# 2  Michael Craig, John Meillon, Eva Griffith, Gra...       5.7           6.0
#
#    ...                                              notes  humor rhythm  \
# ...

# %%
df["genre"].map({"Drama":"drama film"})
# Out:
# 0               NaN
# 1        drama film
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 41394           NaN
# 41395           NaN
# 41396           NaN
# 41397           NaN
# 41398           NaN
# Name: genre, Length: 41399, dtype: object

# %%
data = {
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
}
num_data = pd.DataFrame(data)

# %%
num_data
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
def sum_series(x,y):
    return x+y
result=num_data.apply(lambda ro: sum_series(ro[0],ro[1]),axis=0) 
result
# Out:
# A     3
# B     9
# C    15
# dtype: int64

# %%
df.index.names=["movie_id"]
df
# Out:
#           filmtv_id                                        title  year  \
# movie_id
# 0                 2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1783
# 1                 3                    18 anni tra una settimana  1991
# 2                17                             Ride a Wild Pony  1976
# 3                18                                        Diner  1982
# 4                20              A che servono questi quattrini?  1942
# ...             ...                                          ...   ...
# 41394        232817                           Gold Digger Killer  2021
# 41395        232893                          Addio al nubilato 2  2023
# 41396        232915                                  Konferensen  2023
# 41397        232919                                    Ballelina  2023
# 41398        232920                    Invitación a un Asesinato  2023
#
#               genre  duration                country  \
# movie_id
# ...

# %%
df.rename(columns={"year":"release_year","title":"movie_title"},inplace=True)
df
# Out:
#           filmtv_id                                  movie_title  \
# movie_id
# 0                 2  Bugs Bunny's Third Movie: 1001 Rabbit Tales
# 1                 3                    18 anni tra una settimana
# 2                17                             Ride a Wild Pony
# 3                18                                        Diner
# 4                20              A che servono questi quattrini?
# ...             ...                                          ...
# 41394        232817                           Gold Digger Killer
# 41395        232893                          Addio al nubilato 2
# 41396        232915                                  Konferensen
# 41397        232919                                    Ballelina
# 41398        232920                    Invitación a un Asesinato
#
#           release_year      genre  duration                country  \
# movie_id
# 0                 1783  Animation        76          United States
# ...

# %%
pd.set_option("display.max_rows",3)
pd.set_option("display.max_columns",6)
df
# Out:
#           filmtv_id                                  movie_title  \
# movie_id
# 0                 2  Bugs Bunny's Third Movie: 1001 Rabbit Tales
# ...             ...                                          ...
# 41398        232920                    Invitación a un Asesinato
#
#           release_year  ... must_watch  duration_category voting
# movie_id                ...
# 0                 1783  ...       True              short    152
# ...                ...  ...        ...                ...    ...
# 41398             2023  ...        NaN              short    184
#
# [41399 rows x 23 columns]

# %%
pd.reset_option("display")
df
# Out:
#           filmtv_id                                  movie_title  \
# movie_id
# 0                 2  Bugs Bunny's Third Movie: 1001 Rabbit Tales
# 1                 3                    18 anni tra una settimana
# 2                17                             Ride a Wild Pony
# 3                18                                        Diner
# 4                20              A che servono questi quattrini?
# ...             ...                                          ...
# 41394        232817                           Gold Digger Killer
# 41395        232893                          Addio al nubilato 2
# 41396        232915                                  Konferensen
# 41397        232919                                    Ballelina
# 41398        232920                    Invitación a un Asesinato
#
#           release_year      genre  duration                country  \
# movie_id
# 0                 1783  Animation        76          United States
# ...

# %%
d=df.loc[df["release_year"]>2010]
d
# Out:
#           filmtv_id                movie_title  release_year      genre  \
# movie_id
# 22817         39955           The Tree of Life          2011      Drama
# 23725         41448        Season of the Witch          2011  Adventure
# 24186         42398                   Restless          2011      Drama
# 24426         42847             Qualunquemente          2011  Grotesque
# 24427         42848  Una sconfinata giovinezza          2011      Drama
# ...             ...                        ...           ...        ...
# 41394        232817         Gold Digger Killer          2021   Thriller
# 41395        232893        Addio al nubilato 2          2023     Comedy
# 41396        232915                Konferensen          2023     Horror
# 41397        232919                  Ballelina          2023   Thriller
# 41398        232920  Invitación a un Asesinato          2023   Thriller
#
#           duration                country           directors  \
# movie_id
# ...

# %%
print(df.iloc[2])
# Out:
# filmtv_id                                                           17
# movie_title                                           Ride a Wild Pony
# release_year                                                      1976
# genre                                                         Romantic
# duration                                                            91
# country                                                  United States
# directors                                                  Don Chaffey
# actors               Michael Craig, John Meillon, Eva Griffith, Gra...
# avg_vote                                                           5.7
# critics_vote                                                       6.0
# public_vote                                                        5.0
# total_votes                                                         10
# description          In the Australia of the pioneers, a boy and a ...
# ...

# %%
df.loc[df["duration"]>91,["humor","voting"]]=[100,200]
df.head(10)
# Out:
#           filmtv_id                                  movie_title  \
# movie_id
# 0                 2  Bugs Bunny's Third Movie: 1001 Rabbit Tales
# 1                 3                    18 anni tra una settimana
# 2                17                             Ride a Wild Pony
# 3                18                                        Diner
# 4                20              A che servono questi quattrini?
# 5                21                       The Uranian Conspiracy
# 6                22                            A ciascuno il suo
# 7                23                                    Dead-Bang
# 8                24                          A... come assassino
# 9                26                               At Close Range
#
#           release_year      genre  duration                 country  \
# movie_id
# 0                 1783  Animation        76           United States
# 1                 1991      Drama        98                   Italy
# ...

# %%
df.drop(labels="duration_category",axis=1,inplace=True)
df
# Out:
#           filmtv_id                                  movie_title  \
# movie_id
# 0                 2  Bugs Bunny's Third Movie: 1001 Rabbit Tales
# 1                 3                    18 anni tra una settimana
# 2                17                             Ride a Wild Pony
# 3                18                                        Diner
# 4                20              A che servono questi quattrini?
# ...             ...                                          ...
# 41394        232817                           Gold Digger Killer
# 41395        232893                          Addio al nubilato 2
# 41396        232915                                  Konferensen
# 41397        232919                                    Ballelina
# 41398        232920                    Invitación a un Asesinato
#
#           release_year      genre  duration                country  \
# movie_id
# 0                 1783  Animation        76          United States
# ...

# %%
df["voting_category"]=df["voting"].apply(lambda x: "high" if x>120 else "low")
df
# Out:
#           filmtv_id                                  movie_title  \
# movie_id
# 0                 2  Bugs Bunny's Third Movie: 1001 Rabbit Tales
# 1                 3                    18 anni tra una settimana
# 2                17                             Ride a Wild Pony
# 3                18                                        Diner
# 4                20              A che servono questi quattrini?
# ...             ...                                          ...
# 41394        232817                           Gold Digger Killer
# 41395        232893                          Addio al nubilato 2
# 41396        232915                                  Konferensen
# 41397        232919                                    Ballelina
# 41398        232920                    Invitación a un Asesinato
#
#           release_year      genre  duration                country  \
# movie_id
# 0                 1783  Animation        76          United States
# ...

# %%
df.rename(columns={"voting_category":"voting_strength"},inplace=True)
df
# Out:
#           filmtv_id                                  movie_title  \
# movie_id
# 0                 2  Bugs Bunny's Third Movie: 1001 Rabbit Tales
# 1                 3                    18 anni tra una settimana
# 2                17                             Ride a Wild Pony
# 3                18                                        Diner
# 4                20              A che servono questi quattrini?
# ...             ...                                          ...
# 41394        232817                           Gold Digger Killer
# 41395        232893                          Addio al nubilato 2
# 41396        232915                                  Konferensen
# 41397        232919                                    Ballelina
# 41398        232920                    Invitación a un Asesinato
#
#           release_year      genre  duration                country  \
# movie_id
# 0                 1783  Animation        76          United States
# ...

# %%
df=pd.read_csv("C:/Users/dell/Desktop/ml/web-show 250.csv")
df
# Out:
#      Unnamed: 0                           names relese_date run_time  \
# 0             0                  1 Breaking Bad   2008–2013   62 eps
# 1             1               2 Planet Earth II        2016    6 eps
# 2             2                  3 Planet Earth        2006   11 eps
# 3             3              4 Band of Brothers        2001   10 eps
# 4             4                     5 Chernobyl        2019    5 eps
# ..          ...                             ...         ...      ...
# 245         245              21 The Vietnam War        2017   10 eps
# 246         246                     22 Sherlock   2010–2017   15 eps
# 247         247              23 Attack on Titan   2013–2023   98 eps
# 248         248  24 Batman: The Animated Series   1992–1995   85 eps
# 249         249                   25 The Office   2005–2013  188 eps
#
#     rating_tag  rating
# 0        TV-MA     9.5
# 1         TV-G     9.5
# 2        TV-PG     9.4
# 3        TV-MA     9.4
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0                           names relese_date run_time  \
# 0             0                  1 Breaking Bad   2008–2013   62 eps
# 1             1               2 Planet Earth II        2016    6 eps
# 2             2                  3 Planet Earth        2006   11 eps
# 3             3              4 Band of Brothers        2001   10 eps
# 4             4                     5 Chernobyl        2019    5 eps
# ..          ...                             ...         ...      ...
# 245         245              21 The Vietnam War        2017   10 eps
# 246         246                     22 Sherlock   2010–2017   15 eps
# 247         247              23 Attack on Titan   2013–2023   98 eps
# 248         248  24 Batman: The Animated Series   1992–1995   85 eps
# 249         249                   25 The Office   2005–2013  188 eps
#
#     rating_tag  rating
# 0        TV-MA     9.5
# 1         TV-G     9.5
# 2        TV-PG     9.4
# ...

# %%
long_webseries=df.loc[df["run_time"]>="80 eps"]
long_webseries
# Out:
#      Unnamed: 0                           names relese_date run_time  \
# 8             8                  9 The Sopranos   1999–2007   86 eps
# 22           22              23 Attack on Titan   2013–2023   98 eps
# 23           23  24 Batman: The Animated Series   1992–1995   85 eps
# 33           33                  9 The Sopranos   1999–2007   86 eps
# 47           47              23 Attack on Titan   2013–2023   98 eps
# 48           48  24 Batman: The Animated Series   1992–1995   85 eps
# 58           58                  9 The Sopranos   1999–2007   86 eps
# 72           72              23 Attack on Titan   2013–2023   98 eps
# 73           73  24 Batman: The Animated Series   1992–1995   85 eps
# 83           83                  9 The Sopranos   1999–2007   86 eps
# 97           97              23 Attack on Titan   2013–2023   98 eps
# 98           98  24 Batman: The Animated Series   1992–1995   85 eps
# 108         108                  9 The Sopranos   1999–2007   86 eps
# ...

# %%
multiple_conditions=df.loc[(df["run_time"]=="86 eps") &(df["rating"]>=9.2)]
multiple_conditions.head(2)
# Out:
#     Unnamed: 0           names relese_date run_time rating_tag  rating
# 8            8  9 The Sopranos   1999–2007   86 eps      TV-MA     9.2
# 33          33  9 The Sopranos   1999–2007   86 eps      TV-MA     9.2

# %%
single_condition=df.loc[df["run_time"]=="86 eps"]
single_condition.head(1)
# Out:
#    Unnamed: 0           names relese_date run_time rating_tag  rating
# 8           8  9 The Sopranos   1999–2007   86 eps      TV-MA     9.2

# %%
specific_data=df.iloc[1:10,[1,2,3]]
specific_data
# Out:
#                             names relese_date run_time
# 1               2 Planet Earth II        2016    6 eps
# 2                  3 Planet Earth        2006   11 eps
# 3              4 Band of Brothers        2001   10 eps
# 4                     5 Chernobyl        2019    5 eps
# 5                      6 The Wire   2002–2008   60 eps
# 6    7 Avatar: The Last Airbender   2005–2008   62 eps
# 7                8 Blue Planet II        2017    7 eps
# 8                  9 The Sopranos   1999–2007   86 eps
# 9  10 Cosmos: A Spacetime Odyssey        2014   13 eps

# %%
d=df.iloc[3:10]
d
# Out:
#    Unnamed: 0                           names relese_date run_time rating_tag  \
# 3           3              4 Band of Brothers        2001   10 eps      TV-MA
# 4           4                     5 Chernobyl        2019    5 eps      TV-MA
# 5           5                      6 The Wire   2002–2008   60 eps      TV-MA
# 6           6    7 Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV
# 7           7                8 Blue Planet II        2017    7 eps       TV-G
# 8           8                  9 The Sopranos   1999–2007   86 eps      TV-MA
# 9           9  10 Cosmos: A Spacetime Odyssey        2014   13 eps      TV-PG
#
#    rating
# 3     9.4
# 4     9.3
# 5     9.3
# 6     9.3
# 7     9.3
# 8     9.2
# 9     9.2

# %%
d=df.loc[df["rating_tag"]=="TV-G"]
d
# Out:
#      Unnamed: 0              names relese_date run_time rating_tag  rating
# 1             1  2 Planet Earth II        2016    6 eps       TV-G     9.5
# 7             7   8 Blue Planet II        2017    7 eps       TV-G     9.3
# 17           17            18 Life        2009   11 eps       TV-G     9.1
# 26           26  2 Planet Earth II        2016    6 eps       TV-G     9.5
# 32           32   8 Blue Planet II        2017    7 eps       TV-G     9.3
# 42           42            18 Life        2009   11 eps       TV-G     9.1
# 51           51  2 Planet Earth II        2016    6 eps       TV-G     9.5
# 57           57   8 Blue Planet II        2017    7 eps       TV-G     9.3
# 67           67            18 Life        2009   11 eps       TV-G     9.1
# 76           76  2 Planet Earth II        2016    6 eps       TV-G     9.5
# 82           82   8 Blue Planet II        2017    7 eps       TV-G     9.3
# ...

# %%
a=df.at[20,"names"]
a
# Out:
# '21 The Vietnam War'

# %%
a=df.loc[df["rating"]>9.2]
a
# Out:
#      Unnamed: 0                         names relese_date run_time rating_tag  \
# 0             0                1 Breaking Bad   2008–2013   62 eps      TV-MA
# 1             1             2 Planet Earth II        2016    6 eps       TV-G
# 2             2                3 Planet Earth        2006   11 eps      TV-PG
# 3             3            4 Band of Brothers        2001   10 eps      TV-MA
# 4             4                   5 Chernobyl        2019    5 eps      TV-MA
# ..          ...                           ...         ...      ...        ...
# 231         231  7 Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV
# 232         232              8 Blue Planet II        2017    7 eps       TV-G
# 235         235                     11 Cosmos        1980   13 eps      TV-PG
# 236         236                 12 Our Planet   2019–2023   12 eps      TV-PG
# 239         239                      15 Bluey       2018–  194 eps       TV-Y
#
#      rating
# 0       9.5
# ...

# %%
b=df.loc[df["names"]=="1 Breaking Bad"]
b
# Out:
#      Unnamed: 0           names relese_date run_time rating_tag  rating
# 0             0  1 Breaking Bad   2008–2013   62 eps      TV-MA     9.5
# 25           25  1 Breaking Bad   2008–2013   62 eps      TV-MA     9.5
# 50           50  1 Breaking Bad   2008–2013   62 eps      TV-MA     9.5
# 75           75  1 Breaking Bad   2008–2013   62 eps      TV-MA     9.5
# 100         100  1 Breaking Bad   2008–2013   62 eps      TV-MA     9.5
# 125         125  1 Breaking Bad   2008–2013   62 eps      TV-MA     9.5
# 150         150  1 Breaking Bad   2008–2013   62 eps      TV-MA     9.5
# 175         175  1 Breaking Bad   2008–2013   62 eps      TV-MA     9.5
# 200         200  1 Breaking Bad   2008–2013   62 eps      TV-MA     9.5
# 225         225  1 Breaking Bad   2008–2013   62 eps      TV-MA     9.5

# %%
b=df.iloc[25:100]
b
c=df.at[50,"names"]
c
d=df.at[75,"names"]
d
# Out:
# '1 Breaking Bad'

# %%
df["actors"]="default"
df
# Out:
#      Unnamed: 0                           names relese_date run_time  \
# 0             0                  1 Breaking Bad   2008–2013   62 eps
# 1             1               2 Planet Earth II        2016    6 eps
# 2             2                  3 Planet Earth        2006   11 eps
# 3             3              4 Band of Brothers        2001   10 eps
# 4             4                     5 Chernobyl        2019    5 eps
# ..          ...                             ...         ...      ...
# 245         245              21 The Vietnam War        2017   10 eps
# 246         246                     22 Sherlock   2010–2017   15 eps
# 247         247              23 Attack on Titan   2013–2023   98 eps
# 248         248  24 Batman: The Animated Series   1992–1995   85 eps
# 249         249                   25 The Office   2005–2013  188 eps
#
#     rating_tag  rating   actors
# 0        TV-MA     9.5  default
# 1         TV-G     9.5  default
# 2        TV-PG     9.4  default
# ...

# %%
df.drop(labels="actors",axis=1,inplace=True)
df
# Out:
#      Unnamed: 0                           names relese_date run_time  \
# 0             0                  1 Breaking Bad   2008–2013   62 eps
# 1             1               2 Planet Earth II        2016    6 eps
# 2             2                  3 Planet Earth        2006   11 eps
# 3             3              4 Band of Brothers        2001   10 eps
# 4             4                     5 Chernobyl        2019    5 eps
# ..          ...                             ...         ...      ...
# 245         245              21 The Vietnam War        2017   10 eps
# 246         246                     22 Sherlock   2010–2017   15 eps
# 247         247              23 Attack on Titan   2013–2023   98 eps
# 248         248  24 Batman: The Animated Series   1992–1995   85 eps
# 249         249                   25 The Office   2005–2013  188 eps
#
#     rating_tag  rating
# 0        TV-MA     9.5
# 1         TV-G     9.5
# 2        TV-PG     9.4
# 3        TV-MA     9.4
# ...

# %%
df.at[0,"rating"]=10
df.head(1)
# Out:
#    Unnamed: 0           names relese_date run_time rating_tag  rating
# 0           0  1 Breaking Bad   2008–2013   62 eps      TV-MA    10.0

# %%
df.index.names=["series_id"]
df
# Out:
#            Unnamed: 0                           names relese_date run_time  \
# series_id
# 0                   0                  1 Breaking Bad   2008–2013   62 eps
# 1                   1               2 Planet Earth II        2016    6 eps
# 2                   2                  3 Planet Earth        2006   11 eps
# 3                   3              4 Band of Brothers        2001   10 eps
# 4                   4                     5 Chernobyl        2019    5 eps
# ...               ...                             ...         ...      ...
# 245               245              21 The Vietnam War        2017   10 eps
# 246               246                     22 Sherlock   2010–2017   15 eps
# 247               247              23 Attack on Titan   2013–2023   98 eps
# 248               248  24 Batman: The Animated Series   1992–1995   85 eps
# 249               249                   25 The Office   2005–2013  188 eps
#
#           rating_tag  rating
# series_id
# ...

# %%
df["rating_tag"]=df["rating"].apply(lambda x: "long" if x<9.1 else "short")
df
# Out:
#            Unnamed: 0                           names relese_date run_time  \
# series_id
# 0                   0                  1 Breaking Bad   2008–2013   62 eps
# 1                   1               2 Planet Earth II        2016    6 eps
# 2                   2                  3 Planet Earth        2006   11 eps
# 3                   3              4 Band of Brothers        2001   10 eps
# 4                   4                     5 Chernobyl        2019    5 eps
# ...               ...                             ...         ...      ...
# 245               245              21 The Vietnam War        2017   10 eps
# 246               246                     22 Sherlock   2010–2017   15 eps
# 247               247              23 Attack on Titan   2013–2023   98 eps
# 248               248  24 Batman: The Animated Series   1992–1995   85 eps
# 249               249                   25 The Office   2005–2013  188 eps
#
#           rating_tag  rating
# series_id
# ...

# %%
df.drop(labels="rating_tag",axis=1,inplace=True)
df
# Out:
#            Unnamed: 0                           names relese_date run_time  \
# series_id
# 0                   0                  1 Breaking Bad   2008–2013   62 eps
# 1                   1               2 Planet Earth II        2016    6 eps
# 2                   2                  3 Planet Earth        2006   11 eps
# 3                   3              4 Band of Brothers        2001   10 eps
# 4                   4                     5 Chernobyl        2019    5 eps
# ...               ...                             ...         ...      ...
# 245               245              21 The Vietnam War        2017   10 eps
# 246               246                     22 Sherlock   2010–2017   15 eps
# 247               247              23 Attack on Titan   2013–2023   98 eps
# 248               248  24 Batman: The Animated Series   1992–1995   85 eps
# 249               249                   25 The Office   2005–2013  188 eps
#
#            rating
# series_id
# 0            10.0
# ...

# %%
df.loc[df["names"]=="1 Breaking Bad",["rating","run_time"]]=[9.5,"60 eps"]
df
# Out:
#            Unnamed: 0                           names relese_date run_time  \
# series_id
# 0                   0                  1 Breaking Bad   2008–2013   60 eps
# 1                   1               2 Planet Earth II        2016    6 eps
# 2                   2                  3 Planet Earth        2006   11 eps
# 3                   3              4 Band of Brothers        2001   10 eps
# 4                   4                     5 Chernobyl        2019    5 eps
# ...               ...                             ...         ...      ...
# 245               245              21 The Vietnam War        2017   10 eps
# 246               246                     22 Sherlock   2010–2017   15 eps
# 247               247              23 Attack on Titan   2013–2023   98 eps
# 248               248  24 Batman: The Animated Series   1992–1995   85 eps
# 249               249                   25 The Office   2005–2013  188 eps
#
#            rating
# series_id
# 0             9.5
# ...

# %%
d=df.iloc[1:10]
d.names
# Out:
# series_id
# 1                 2 Planet Earth II
# 2                    3 Planet Earth
# 3                4 Band of Brothers
# 4                       5 Chernobyl
# 5                        6 The Wire
# 6      7 Avatar: The Last Airbender
# 7                  8 Blue Planet II
# 8                    9 The Sopranos
# 9    10 Cosmos: A Spacetime Odyssey
# Name: names, dtype: object

# %%
df.head(5)
# Out:
#            Unnamed: 0               names relese_date run_time  rating
# series_id
# 0                   0      1 Breaking Bad   2008–2013   60 eps     9.5
# 1                   1   2 Planet Earth II        2016    6 eps     9.5
# 2                   2      3 Planet Earth        2006   11 eps     9.4
# 3                   3  4 Band of Brothers        2001   10 eps     9.4
# 4                   4         5 Chernobyl        2019    5 eps     9.3

# %%
release_date_groups=df.groupby("rating")
release_date_groups.head()
# Out:
#            Unnamed: 0                                names relese_date  \
# series_id
# 0                   0                       1 Breaking Bad   2008–2013
# 1                   1                    2 Planet Earth II        2016
# 2                   2                       3 Planet Earth        2006
# 3                   3                   4 Band of Brothers        2001
# 4                   4                          5 Chernobyl        2019
# 5                   5                           6 The Wire   2002–2008
# 6                   6         7 Avatar: The Last Airbender   2005–2008
# 7                   7                     8 Blue Planet II        2017
# 8                   8                       9 The Sopranos   1999–2007
# 9                   9       10 Cosmos: A Spacetime Odyssey        2014
# 10                 10                            11 Cosmos        1980
# 12                 12                   13 Game of Thrones   2011–2019
# ...

# %%
release_date_groups=df.groupby(["rating","relese_date"])
release_date_groups.head()
# Out:
#            Unnamed: 0                           names relese_date run_time  \
# series_id
# 0                   0                  1 Breaking Bad   2008–2013   60 eps
# 1                   1               2 Planet Earth II        2016    6 eps
# 2                   2                  3 Planet Earth        2006   11 eps
# 3                   3              4 Band of Brothers        2001   10 eps
# 4                   4                     5 Chernobyl        2019    5 eps
# ...               ...                             ...         ...      ...
# 120               120              21 The Vietnam War        2017   10 eps
# 121               121                     22 Sherlock   2010–2017   15 eps
# 122               122              23 Attack on Titan   2013–2023   98 eps
# 123               123  24 Batman: The Animated Series   1992–1995   85 eps
# 124               124                   25 The Office   2005–2013  188 eps
#
#            rating
# series_id
# 0             9.5
# ...

# %%
avg_rating_by_runtime=df.groupby("run_time")["rating"].mean()
avg_rating_by_runtime
# Out:
# run_time
# 10 eps     9.20
# 11 eps     9.25
# 12 eps     9.30
# 13 eps     9.25
# 15 eps     9.10
# 156 eps    9.10
# 188 eps    9.00
# 194 eps    9.40
# 26 eps     9.20
# 5 eps      9.30
# 6 eps      9.50
# 60 eps     9.40
# 62 eps     9.30
# 68 eps     9.10
# 7 eps      9.30
# 74 eps     9.15
# 85 eps     9.00
# 86 eps     9.20
# 98 eps     9.10
# Name: rating, dtype: float64

# %%
stats_by_runtime=df.groupby("run_time")["rating"].agg([np.mean,np.std,np.min,np.max])
stats_by_runtime.head()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11552\1154789946.py:1: FutureWarning: The provided callable <function mean at 0x00000209433C4CC0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   stats_by_runtime=df.groupby("run_time")["rating"].agg([np.mean,np.std,np.min,np.max])
# C:\Users\dell\AppData\Local\Temp\ipykernel_11552\1154789946.py:1: FutureWarning: The provided callable <function std at 0x00000209433C4E00> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   stats_by_runtime=df.groupby("run_time")["rating"].agg([np.mean,np.std,np.min,np.max])
# ...

# %%
stats_by_runtime=df.groupby("run_time")["rating"].agg([np.mean,np.std,np.min,np.max])
stats_by_runtime.head()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11552\1154789946.py:1: FutureWarning: The provided callable <function mean at 0x00000209433C4CC0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   stats_by_runtime=df.groupby("run_time")["rating"].agg([np.mean,np.std,np.min,np.max])
# C:\Users\dell\AppData\Local\Temp\ipykernel_11552\1154789946.py:1: FutureWarning: The provided callable <function std at 0x00000209433C4E00> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   stats_by_runtime=df.groupby("run_time")["rating"].agg([np.mean,np.std,np.min,np.max])
# ...

# %%
a=df["rating"].describe()
a
# Out:
# count    250.000000
# mean       9.224000
# std        0.142496
# min        9.000000
# 25%        9.100000
# 50%        9.200000
# 75%        9.300000
# max        9.500000
# Name: rating, dtype: float64

# %%
data={"A":[1,2,None],"B":[4,None,6],"C":[5,8,9]}
data_df=pd.DataFrame(data)
data_df
# Out:
#      A    B  C
# 0  1.0  4.0  5
# 1  2.0  NaN  8
# 2  NaN  6.0  9

# %%
counts=data_df.count()
counts
# Out:
# A    2
# B    2
# C    3
# dtype: int64

# %%
df["rating"].value_counts()
# Out:
# rating
# 9.1    80
# 9.3    60
# 9.2    40
# 9.4    30
# 9.5    20
# 9.0    20
# Name: count, dtype: int64
